# %% [markdown]
# ##Import data
# To import data, it is useful to mount your google drive using the function 'drive.mount'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##importing important tools
# import matplotlib.pyplot, numpy and pandas to be able to perform certain tasks using code

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #importing and showing data
# use the function 'df=pd.read_csv' and 'df.head()' to visualize data

# %%
df=pd.read_csv('gdrive/My Drive/CountyHealthData_2014-2015.csv')
df.head()
# Out:
#   State Region Division                      County  FIPS  GEOID   SMS Region  \
# 0    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 1    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 2    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 3    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 4    AK   West  Pacific          Bethel Census Area  2050   2050  Insuff Data
#
#        Year  Premature death  Poor or fair health  ...  Drug poisoning deaths  \
# 0  1/1/2014              NaN                0.122  ...                    NaN
# 1  1/1/2015              NaN                0.122  ...                    NaN
# 2  1/1/2014           6827.0                0.125  ...                  15.37
# 3  1/1/2015           6856.0                0.125  ...                  17.08
# 4  1/1/2014          13345.0                0.211  ...                    NaN
#
# ...

# %% [markdown]
# #show only North Carolina
# use df to show only a certain state, for example NC

# %%
df[df["State"]== "NC"]
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %%
NC_subset = df[df["State"]== "NC"].copy()

# %%
NC_subset
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %%
NC_subset.to_csv("NC_subset.csv", index=False)

# %% [markdown]
# #To Show only one division
# Use .loc to show a specific category and a certain amount of the data

# %%
df.loc[0:3,"Division"]
# Out:
# 0    Pacific
# 1    Pacific
# 2    Pacific
# 3    Pacific
# Name: Division, dtype: object

# %%
df.loc[105:110,"State"]
# Out:
# 105    AL
# 106    AL
# 107    AL
# 108    AL
# 109    AL
# 110    AL
# Name: State, dtype: object

# %%
df.loc[0:3,["State","County","Food environment index"]]
# Out:
#   State                      County  Food environment index
# 0    AK  Aleutians West Census Area                   7.002
# 1    AK  Aleutians West Census Area                   6.600
# 2    AK           Anchorage Borough                   8.185
# 3    AK           Anchorage Borough                   8.000

# %%
df.loc[:,["State","County","Health care costs"]].head() #these may be the correct graphs to be using
# Out:
#   State                      County  Health care costs
# 0    AK  Aleutians West Census Area             3791.0
# 1    AK  Aleutians West Census Area             4837.0
# 2    AK           Anchorage Borough             6588.0
# 3    AK           Anchorage Borough             6582.0
# 4    AK          Bethel Census Area             5860.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Health care costs'].plot(kind='hist', bins=20, title='Health care costs')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('County').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
#concatenate
pd.concat

# %% [markdown]
# #Creating Charts
# Use pyplot to create certain charts, for example a bar chart. import a color using a code or color name, alter what data is showing by changing the xlimit

# %%
df.plot(kind='bar', x='State', y='Uninsured adults', color = 'xkcd:sky blue')
plt.xlim(35, 70) #moving the x limit can show new states, but i need to randomize to show multiple states
plt.show()

# %%
df.plot(kind='bar', x='State', y='Poor or fair health', color = '#E6E6FA')
plt.xlim(35, 70) #moving the x limit can show new states, but i need to randomize to show multiple states
plt.show()

# %%
df.plot(kind='bar', x='State', y='Premature death', color = 'lightpink')
plt.xlim(500, 550)
plt.show()
